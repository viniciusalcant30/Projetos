# %% [markdown]
# **Vector Field** *13/11*
#  EXERCÍCIO 5
#
#  $y' = x$

# %%
# Vector field

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


# posições x e y no plano 
x,y = np.meshgrid(np.linspace(-5,5,20),np.linspace(-5,5,20)) #x e y representa a localização no espaço 
  
# derivadas
dy = x 
dx = np.ones(dy.shape)  

plt.figure(figsize=(8, 8))
plt.title("Vector Field: y'=x")
plt.quiver(x,y,dx,dy)
plt.show()

# %%
# posições x e y no plano 
x,y = np.meshgrid(np.linspace(-5,5,10),np.linspace(-5,5,10)) #x e y representa a localização no espaço 
  
# derivadas
dy = x 
dx = np.ones(dy.shape) 


plt.figure(figsize=(10, 10))
plt.streamplot(x, y, dx, dy, density=1.4, linewidth=None, color='#A23BEC')
plt.title("Vector Field: y'=x")
  

plt.grid()
plt.show()
